# %%
import requests
import requests_mock
from requests.compat import urljoin

# %%
class DataGrabber():
    def __init__(self):
        self.url = 'http://api.wunderground.com/api/'
        self.key = '167bacfb55bf6c78/'
        self.features = 'alerts/astronomy/conditions/currenthurricane/forecast10day/'
    
    def grab(self, zipcode):
        response = requests.get('{}{}{}q/{}.json'.format(self.url, self.key, self.features, zipcode))
        data = response.json()
        return data

# %%
zipcode = 27514
grabber = DataGrabber()
data = grabber.grab(zipcode)
data
# Out:
# {'alerts': [],
#  'current_observation': {'UV': '0',
#   'dewpoint_c': 20,
#   'dewpoint_f': 68,
#   'dewpoint_string': '68 F (20 C)',
#   'display_location': {'city': 'Chapel Hill',
#    'country': 'US',
#    'country_iso3166': 'US',
#    'elevation': '122.00000000',
#    'full': 'Chapel Hill, NC',
#    'latitude': '35.93691635',
#    'longitude': '-79.03968811',
#    'magic': '1',
#    'state': 'NC',
#    'state_name': 'North Carolina',
#    'wmo': '99999',
#    'zip': '27514'},
#   'estimated': {},
#   'feelslike_c': '21.7',
#   'feelslike_f': '71.1',
#   'feelslike_string': '71.1 F (21.7 C)',
#   'forecast_url': 'http://www.wunderground.com/US/NC/Chapel_Hill.html',
#   'heat_index_c': 'NA',
#   'heat_index_f': 'NA',
#   'heat_index_string': 'NA',
#   'history_url': 'http://www.wunderground.com/weatherstation/WXDailyHistory.asp?ID=KNCCHAPE17',
#   'icon': 'clear',
#   'icon_url': 'http://icons.wxug.com/i/c/k/nt_clear.gif',
#   'image': {'link': 'http://www.wunderground.com',
#    'title': 'Weather Underground',
#    'url': 'http://icons.wxug.com/graphics/wu2/logo_130x80.png'},
#   'local_epoch': '1463018468',
#   'local_time_rfc822': 'Wed, 11 May 2016 22:01:08 -0400',
#   'local_tz_long': 'America/New_York',
#   'local_tz_offset': '-0400',
#   'local_tz_short': 'EDT',
#   'nowcast': '',
#   'ob_url': 'http://www.wunderground.com/cgi-bin/findweather/getForecast?query=35.945217,-79.018547',
#   'observation_epoch': '1463018465',
#   'observation_location': {'city': 'Cosgrove Hill, Chapel Hill',
#    'country': 'US',
#    'country_iso3166': 'US',
#    'elevation': '325 ft',
#    'full': 'Cosgrove Hill, Chapel Hill, North Carolina',
#    'latitude': '35.945217',
#    'longitude': '-79.018547',
#    'state': 'North Carolina'},
#   'observation_time': 'Last Updated on May 11, 10:01 PM EDT',
#   'observation_time_rfc822': 'Wed, 11 May 2016 22:01:05 -0400',
#   'precip_1hr_in': '0.00',
#   'precip_1hr_metric': ' 0',
#   'precip_1hr_string': '0.00 in ( 0 mm)',
#   'precip_today_in': '0.00',
#   'precip_today_metric': '0',
#   'precip_today_string': '0.00 in (0 mm)',
#   'pressure_in': '30.09',
#   'pressure_mb': '1019',
#   'pressure_trend': '+',
#   'relative_humidity': '92%',
#   'solarradiation': '--',
#   'station_id': 'KNCCHAPE17',
#   'temp_c': 21.7,
#   'temp_f': 71.1,
#   'temperature_string': '71.1 F (21.7 C)',
#   'visibility_km': '16.1',
#   'visibility_mi': '10.0',
#   'weather': 'Clear',
#   'wind_degrees': 352,
#   'wind_dir': 'North',
#   'wind_gust_kph': 0,
#   'wind_gust_mph': 0,
#   'wind_kph': 0,
#   'wind_mph': 0.0,
#   'wind_string': 'Calm',
#   'windchill_c': 'NA',
#   'windchill_f': 'NA',
#   'windchill_string': 'NA'},
#  'currenthurricane': [],
#  'forecast': {'simpleforecast': {'forecastday': [{'avehumidity': 92,
#      'avewind': {'degrees': 0, 'dir': 'WSW', 'kph': 2, 'mph': 1},
#      'conditions': 'Partly Cloudy',
#      'date': {'ampm': 'PM',
#       'day': 11,
#       'epoch': '1463007600',
#       'hour': 19,
#       'isdst': '1',
#       'min': '00',
#       'month': 5,
#       'monthname': 'May',
#       'monthname_short': 'May',
#       'pretty': '7:00 PM EDT on May 11, 2016',
#       'sec': 0,
#       'tz_long': 'America/New_York',
#       'tz_short': 'EDT',
#       'weekday': 'Wednesday',
#       'weekday_short': 'Wed',
#       'yday': 131,
#       'year': 2016},
#      'high': {'celsius': '27', 'fahrenheit': '81'},
#      'icon': 'partlycloudy',
#      'icon_url': 'http://icons.wxug.com/i/c/k/partlycloudy.gif',
#      'low': {'celsius': '17', 'fahrenheit': '62'},
#      'maxhumidity': 0,
#      'maxwind': {'degrees': 0, 'dir': 'West', 'kph': 13, 'mph': 8},
#      'minhumidity': 0,
#      'period': 1,
#      'pop': 20,
#      'qpf_allday': {'in': 0.0, 'mm': 0},
#      'qpf_day': {'in': None, 'mm': None},
#      'qpf_night': {'in': 0.0, 'mm': 0},
#      'skyicon': '',
#      'snow_allday': {'cm': 0.0, 'in': 0.0},
#      'snow_day': {'cm': None, 'in': None},
#      'snow_night': {'cm': 0.0, 'in': 0.0}},
#     {'avehumidity': 71,
#      'avewind': {'degrees': 59, 'dir': 'ENE', 'kph': 5, 'mph': 3},
#      'conditions': 'Partly Cloudy',
#      'date': {'ampm': 'PM',
#       'day': 12,
#       'epoch': '1463094000',
#       'hour': 19,
#       'isdst': '1',
#       'min': '00',
#       'month': 5,
#       'monthname': 'May',
#       'monthname_short': 'May',
#       'pretty': '7:00 PM EDT on May 12, 2016',
#       'sec': 0,
#       'tz_long': 'America/New_York',
#       'tz_short': 'EDT',
#       'weekday': 'Thursday',
#       'weekday_short': 'Thu',
#       'yday': 132,
#       'year': 2016},
#      'high': {'celsius': '28', 'fahrenheit': '82'},
#      'icon': 'partlycloudy',
#      'icon_url': 'http://icons.wxug.com/i/c/k/partlycloudy.gif',
#      'low': {'celsius': '18', 'fahrenheit': '65'},
#      'maxhumidity': 0,
#      'maxwind': {'degrees': 59, 'dir': 'ENE', 'kph': 8, 'mph': 5},
#      'minhumidity': 0,
#      'period': 2,
#      'pop': 20,
#      'qpf_allday': {'in': 0.04, 'mm': 1},
#      'qpf_day': {'in': 0.0, 'mm': 0},
#      'qpf_night': {'in': 0.04, 'mm': 1},
#      'skyicon': '',
#      'snow_allday': {'cm': 0.0, 'in': 0.0},
#      'snow_day': {'cm': 0.0, 'in': 0.0},
#      'snow_night': {'cm': 0.0, 'in': 0.0}},
#     {'avehumidity': 69,
#      'avewind': {'degrees': 279, 'dir': 'W', 'kph': 11, 'mph': 7},
#      'conditions': 'Chance of a Thunderstorm',
#      'date': {'ampm': 'PM',
#       'day': 13,
#       'epoch': '1463180400',
#       'hour': 19,
#       'isdst': '1',
#       'min': '00',
#       'month': 5,
#       'monthname': 'May',
#       'monthname_short': 'May',
#       'pretty': '7:00 PM EDT on May 13, 2016',
#       'sec': 0,
#       'tz_long': 'America/New_York',
#       'tz_short': 'EDT',
#       'weekday': 'Friday',
#       'weekday_short': 'Fri',
#       'yday': 133,
#       'year': 2016},
#      'high': {'celsius': '26', 'fahrenheit': '78'},
#      'icon': 'chancetstorms',
#      'icon_url': 'http://icons.wxug.com/i/c/k/chancetstorms.gif',
#      'low': {'celsius': '13', 'fahrenheit': '56'},
#      'maxhumidity': 0,
#      'maxwind': {'degrees': 279, 'dir': 'W', 'kph': 16, 'mph': 10},
#      'minhumidity': 0,
#      'period': 3,
#      'pop': 60,
#      'qpf_allday': {'in': 0.17, 'mm': 4},
#      'qpf_day': {'in': 0.17, 'mm': 4},
#      'qpf_night': {'in': 0.0, 'mm': 0},
#      'skyicon': '',
#      'snow_allday': {'cm': 0.0, 'in': 0.0},
#      'snow_day': {'cm': 0.0, 'in': 0.0},
#      'snow_night': {'cm': 0.0, 'in': 0.0}},
#     {'avehumidity': 46,
#      'avewind': {'degrees': 272, 'dir': 'W', 'kph': 16, 'mph': 10},
#      'conditions': 'Partly Cloudy',
#      'date': {'ampm': 'PM',
#       'day': 14,
#       'epoch': '1463266800',
#       'hour': 19,
#       'isdst': '1',
#       'min': '00',
#       'month': 5,
#       'monthname': 'May',
#       'monthname_short': 'May',
#       'pretty': '7:00 PM EDT on May 14, 2016',
#       'sec': 0,
#       'tz_long': 'America/New_York',
#       'tz_short': 'EDT',
#       'weekday': 'Saturday',
#       'weekday_short': 'Sat',
#       'yday': 134,
#       'year': 2016},
#      'high': {'celsius': '28', 'fahrenheit': '82'},
#      'icon': 'partlycloudy',
#      'icon_url': 'http://icons.wxug.com/i/c/k/partlycloudy.gif',
#      'low': {'celsius': '9', 'fahrenheit': '49'},
#      'maxhumidity': 0,
#      'maxwind': {'degrees': 272, 'dir': 'W', 'kph': 24, 'mph': 15},
#      'minhumidity': 0,
#      'period': 4,
#      'pop': 20,
#      'qpf_allday': {'in': 0.0, 'mm': 0},
#      'qpf_day': {'in': 0.0, 'mm': 0},
#      'qpf_night': {'in': 0.0, 'mm': 0},
#      'skyicon': '',
#      'snow_allday': {'cm': 0.0, 'in': 0.0},
#      'snow_day': {'cm': 0.0, 'in': 0.0},
#      'snow_night': {'cm': 0.0, 'in': 0.0}},
#     {'avehumidity': 39,
#      'avewind': {'degrees': 298, 'dir': 'WNW', 'kph': 13, 'mph': 8},
#      'conditions': 'Clear',
#      'date': {'ampm': 'PM',
#       'day': 15,
#       'epoch': '1463353200',
#       'hour': 19,
#       'isdst': '1',
#       'min': '00',
#       'month': 5,
#       'monthname': 'May',
#       'monthname_short': 'May',
#       'pretty': '7:00 PM EDT on May 15, 2016',
#       'sec': 0,
#       'tz_long': 'America/New_York',
#       'tz_short': 'EDT',
#       'weekday': 'Sunday',
#       'weekday_short': 'Sun',
#       'yday': 135,
#       'year': 2016},
#      'high': {'celsius': '22', 'fahrenheit': '72'},
#      'icon': 'clear',
#      'icon_url': 'http://icons.wxug.com/i/c/k/clear.gif',
#      'low': {'celsius': '11', 'fahrenheit': '51'},
#      'maxhumidity': 0,
#      'maxwind': {'degrees': 298, 'dir': 'WNW', 'kph': 16, 'mph': 10},
#      'minhumidity': 0,
#      'period': 5,
#      'pop': 0,
#      'qpf_allday': {'in': 0.0, 'mm': 0},
#      'qpf_day': {'in': 0.0, 'mm': 0},
#      'qpf_night': {'in': 0.0, 'mm': 0},
#      'skyicon': '',
#      'snow_allday': {'cm': 0.0, 'in': 0.0},
#      'snow_day': {'cm': 0.0, 'in': 0.0},
#      'snow_night': {'cm': 0.0, 'in': 0.0}},
#     {'avehumidity': 41,
#      'avewind': {'degrees': 58, 'dir': 'ENE', 'kph': 5, 'mph': 3},
#      'conditions': 'Partly Cloudy',
#      'date': {'ampm': 'PM',
#       'day': 16,
#       'epoch': '1463439600',
#       'hour': 19,
#       'isdst': '1',
#       'min': '00',
#       'month': 5,
#       'monthname': 'May',
#       'monthname_short': 'May',
#       'pretty': '7:00 PM EDT on May 16, 2016',
#       'sec': 0,
#       'tz_long': 'America/New_York',
#       'tz_short': 'EDT',
#       'weekday': 'Monday',
#       'weekday_short': 'Mon',
#       'yday': 136,
#       'year': 2016},
#      'high': {'celsius': '23', 'fahrenheit': '73'},
#      'icon': 'partlycloudy',
#      'icon_url': 'http://icons.wxug.com/i/c/k/partlycloudy.gif',
#      'low': {'celsius': '13', 'fahrenheit': '55'},
#      'maxhumidity': 0,
#      'maxwind': {'degrees': 58, 'dir': 'ENE', 'kph': 8, 'mph': 5},
#      'minhumidity': 0,
#      'period': 6,
#      'pop': 0,
#      'qpf_allday': {'in': 0.0, 'mm': 0},
#      'qpf_day': {'in': 0.0, 'mm': 0},
#      'qpf_night': {'in': 0.0, 'mm': 0},
#      'skyicon': '',
#      'snow_allday': {'cm': 0.0, 'in': 0.0},
#      'snow_day': {'cm': 0.0, 'in': 0.0},
#      'snow_night': {'cm': 0.0, 'in': 0.0}},
#     {'avehumidity': 58,
#      'avewind': {'degrees': 113, 'dir': 'ESE', 'kph': 10, 'mph': 6},
#      'conditions': 'Chance of Rain',
#      'date': {'ampm': 'PM',
#       'day': 17,
#       'epoch': '1463526000',
#       'hour': 19,
#       'isdst': '1',
#       'min': '00',
#       'month': 5,
#       'monthname': 'May',
#       'monthname_short': 'May',
#       'pretty': '7:00 PM EDT on May 17, 2016',
#       'sec': 0,
#       'tz_long': 'America/New_York',
#       'tz_short': 'EDT',
#       'weekday': 'Tuesday',
#       'weekday_short': 'Tue',
#       'yday': 137,
#       'year': 2016},
#      'high': {'celsius': '26', 'fahrenheit': '78'},
#      'icon': 'chancerain',
#      'icon_url': 'http://icons.wxug.com/i/c/k/chancerain.gif',
#      'low': {'celsius': '18', 'fahrenheit': '64'},
#      'maxhumidity': 0,
#      'maxwind': {'degrees': 113, 'dir': 'ESE', 'kph': 16, 'mph': 10},
#      'minhumidity': 0,
#      'period': 7,
#      'pop': 60,
#      'qpf_allday': {'in': 0.45, 'mm': 11},
#      'qpf_day': {'in': 0.13, 'mm': 3},
#      'qpf_night': {'in': 0.31, 'mm': 8},
#      'skyicon': '',
#      'snow_allday': {'cm': 0.0, 'in': 0.0},
#      'snow_day': {'cm': 0.0, 'in': 0.0},
#      'snow_night': {'cm': 0.0, 'in': 0.0}},
#     {'avehumidity': 68,
#      'avewind': {'degrees': 219, 'dir': 'SW', 'kph': 14, 'mph': 9},
#      'conditions': 'Chance of a Thunderstorm',
#      'date': {'ampm': 'PM',
#       'day': 18,
#       'epoch': '1463612400',
#       'hour': 19,
#       'isdst': '1',
#       'min': '00',
#       'month': 5,
#       'monthname': 'May',
#       'monthname_short': 'May',
#       'pretty': '7:00 PM EDT on May 18, 2016',
#       'sec': 0,
#       'tz_long': 'America/New_York',
#       'tz_short': 'EDT',
#       'weekday': 'Wednesday',
#       'weekday_short': 'Wed',
#       'yday': 138,
#       'year': 2016},
#      'high': {'celsius': '28', 'fahrenheit': '82'},
#      'icon': 'chancetstorms',
#      'icon_url': 'http://icons.wxug.com/i/c/k/chancetstorms.gif',
#      'low': {'celsius': '18', 'fahrenheit': '65'},
#      'maxhumidity': 0,
#      'maxwind': {'degrees': 219, 'dir': 'SW', 'kph': 16, 'mph': 10},
#      'minhumidity': 0,
#      'period': 8,
#      'pop': 60,
#      'qpf_allday': {'in': 0.27, 'mm': 7},
#      'qpf_day': {'in': 0.13, 'mm': 3},
#      'qpf_night': {'in': 0.14, 'mm': 4},
#      'skyicon': '',
#      'snow_allday': {'cm': 0.0, 'in': 0.0},
#      'snow_day': {'cm': 0.0, 'in': 0.0},
#      'snow_night': {'cm': 0.0, 'in': 0.0}},
#     {'avehumidity': 72,
#      'avewind': {'degrees': 237, 'dir': 'WSW', 'kph': 10, 'mph': 6},
#      'conditions': 'Chance of a Thunderstorm',
#      'date': {'ampm': 'PM',
#       'day': 19,
#       'epoch': '1463698800',
#       'hour': 19,
#       'isdst': '1',
#       'min': '00',
#       'month': 5,
#       'monthname': 'May',
#       'monthname_short': 'May',
#       'pretty': '7:00 PM EDT on May 19, 2016',
#       'sec': 0,
#       'tz_long': 'America/New_York',
#       'tz_short': 'EDT',
#       'weekday': 'Thursday',
#       'weekday_short': 'Thu',
#       'yday': 139,
#       'year': 2016},
#      'high': {'celsius': '28', 'fahrenheit': '82'},
#      'icon': 'chancetstorms',
#      'icon_url': 'http://icons.wxug.com/i/c/k/chancetstorms.gif',
#      'low': {'celsius': '18', 'fahrenheit': '65'},
#      'maxhumidity': 0,
#      'maxwind': {'degrees': 237, 'dir': 'WSW', 'kph': 16, 'mph': 10},
#      'minhumidity': 0,
#      'period': 9,
#      'pop': 60,
#      'qpf_allday': {'in': 0.19, 'mm': 5},
#      'qpf_day': {'in': 0.16, 'mm': 4},
#      'qpf_night': {'in': 0.03, 'mm': 1},
#      'skyicon': '',
#      'snow_allday': {'cm': 0.0, 'in': 0.0},
#      'snow_day': {'cm': 0.0, 'in': 0.0},
#      'snow_night': {'cm': 0.0, 'in': 0.0}},
#     {'avehumidity': 69,
#      'avewind': {'degrees': 288, 'dir': 'WNW', 'kph': 10, 'mph': 6},
#      'conditions': 'Chance of Rain',
#      'date': {'ampm': 'PM',
#       'day': 20,
#       'epoch': '1463785200',
#       'hour': 19,
#       'isdst': '1',
#       'min': '00',
#       'month': 5,
#       'monthname': 'May',
#       'monthname_short': 'May',
#       'pretty': '7:00 PM EDT on May 20, 2016',
#       'sec': 0,
#       'tz_long': 'America/New_York',
#       'tz_short': 'EDT',
#       'weekday': 'Friday',
#       'weekday_short': 'Fri',
#       'yday': 140,
#       'year': 2016},
#      'high': {'celsius': '27', 'fahrenheit': '80'},
#      'icon': 'chancerain',
#      'icon_url': 'http://icons.wxug.com/i/c/k/chancerain.gif',
#      'low': {'celsius': '17', 'fahrenheit': '63'},
#      'maxhumidity': 0,
#      'maxwind': {'degrees': 288, 'dir': 'WNW', 'kph': 16, 'mph': 10},
#      'minhumidity': 0,
#      'period': 10,
#      'pop': 30,
#      'qpf_allday': {'in': 0.19, 'mm': 5},
#      'qpf_day': {'in': 0.01, 'mm': 0},
#      'qpf_night': {'in': 0.18, 'mm': 5},
#      'skyicon': '',
#      'snow_allday': {'cm': 0.0, 'in': 0.0},
#      'snow_day': {'cm': 0.0, 'in': 0.0},
#      'snow_night': {'cm': 0.0, 'in': 0.0}}]},
#   'txt_forecast': {'date': '8:31 PM EDT',
#    'forecastday': [{'fcttext': 'Partly cloudy. Lows overnight in the low 60s.',
#      'fcttext_metric': 'Showers and thunderstorms early. Low 17C.',
#      'icon': 'partlycloudy',
#      'icon_url': 'http://icons.wxug.com/i/c/k/partlycloudy.gif',
#      'period': 0,
#      'pop': '20',
#      'title': 'Wednesday'},
#     {'fcttext': 'Partly to mostly cloudy. A stray shower or thunderstorm is possible. Low 62F. Winds light and variable.',
#      'fcttext_metric': 'Thunderstorms during the evening will give way to mostly cloudy skies after midnight. Low 17C. Winds light and variable. Chance of rain 80%.',
#      'icon': 'nt_partlycloudy',
#      'icon_url': 'http://icons.wxug.com/i/c/k/nt_partlycloudy.gif',
#      'period': 1,
#      'pop': '20',
#      'title': 'Wednesday Night'},
#     {'fcttext': 'Cloudy early with partial sunshine expected late. A stray shower or thunderstorm is possible. High 82F. Winds light and variable.',
#      'fcttext_metric': 'Mostly cloudy skies. A stray shower or thunderstorm is possible. High 29C. Winds light and variable.',
#      'icon': 'partlycloudy',
#      'icon_url': 'http://icons.wxug.com/i/c/k/partlycloudy.gif',
#      'period': 2,
#      'pop': '20',
#      'title': 'Thursday'},
#     {'fcttext': 'Scattered thunderstorms in the evening. Partly cloudy skies overnight. Low around 65F. Winds light and variable. Chance of rain 50%.',
#      'fcttext_metric': 'Mostly cloudy with scattered thunderstorms mainly before midnight. Low 18C. Winds light and variable. Chance of rain 50%.',
#      'icon': 'nt_chancetstorms',
#      'icon_url': 'http://icons.wxug.com/i/c/k/nt_chancetstorms.gif',
#      'period': 3,
#      'pop': '50',
#      'title': 'Thursday Night'},
#     {'fcttext': 'Scattered showers and thunderstorms. High 78F. Winds W at 5 to 10 mph. Chance of rain 60%.',
#      'fcttext_metric': 'Scattered thunderstorms in the morning becoming more widespread in the afternoon. High 26C. Winds W at 10 to 15 km/h. Chance of rain 80%.',
#      'icon': 'chancetstorms',
#      'icon_url': 'http://icons.wxug.com/i/c/k/chancetstorms.gif',
#      'period': 4,
#      'pop': '60',
#      'title': 'Friday'},
#     {'fcttext': 'Partly cloudy skies. Low 56F. Winds light and variable.',
#      'fcttext_metric': 'Partly cloudy skies. Low 13C. Winds light and variable.',
#      'icon': 'nt_partlycloudy',
#      'icon_url': 'http://icons.wxug.com/i/c/k/nt_partlycloudy.gif',
#      'period': 5,
#      'pop': '0',
#      'title': 'Friday Night'},
#     {'fcttext': 'Sunshine and clouds mixed. A stray shower or thunderstorm is possible. High 82F. Winds W at 10 to 15 mph.',
#      'fcttext_metric': 'Partly cloudy. A stray shower or thunderstorm is possible. High 29C. Winds W at 15 to 25 km/h.',
#      'icon': 'partlycloudy',
#      'icon_url': 'http://icons.wxug.com/i/c/k/partlycloudy.gif',
#      'period': 6,
#      'pop': '20',
#      'title': 'Saturday'},
#     {'fcttext': 'Some clouds early will give way to generally clear conditions overnight. Low 49F. Winds NW at 5 to 10 mph.',
#      'fcttext_metric': 'Partly cloudy skies. Low around 10C. Winds NW at 10 to 15 km/h.',
#      'icon': 'nt_partlycloudy',
#      'icon_url': 'http://icons.wxug.com/i/c/k/nt_partlycloudy.gif',
#      'period': 7,
#      'pop': '0',
#      'title': 'Saturday Night'},
#     {'fcttext': 'Mainly sunny. High 72F. Winds WNW at 5 to 10 mph.',
#      'fcttext_metric': 'Sunny. High 23C. Winds WNW at 10 to 15 km/h.',
#      'icon': 'clear',
#      'icon_url': 'http://icons.wxug.com/i/c/k/clear.gif',
#      'period': 8,
#      'pop': '0',
#      'title': 'Sunday'},
#     {'fcttext': 'Clear skies with a few passing clouds. Low 51F. Winds light and variable.',
#      'fcttext_metric': 'Mainly clear skies. Low 11C. Winds light and variable.',
#      'icon': 'nt_clear',
#      'icon_url': 'http://icons.wxug.com/i/c/k/nt_clear.gif',
#      'period': 9,
#      'pop': '20',
#      'title': 'Sunday Night'},
#     {'fcttext': 'Partly cloudy skies. High 73F. Winds light and variable.',
#      'fcttext_metric': 'Sunshine and clouds mixed. High 24C. Winds light and variable.',
#      'icon': 'partlycloudy',
#      'icon_url': 'http://icons.wxug.com/i/c/k/partlycloudy.gif',
#      'period': 10,
#      'pop': '0',
#      'title': 'Monday'},
#     {'fcttext': 'A few clouds. Low near 55F. Winds light and variable.',
#      'fcttext_metric': 'A few clouds from time to time. Low 13C. Winds light and variable.',
#      'icon': 'nt_partlycloudy',
#      'icon_url': 'http://icons.wxug.com/i/c/k/nt_partlycloudy.gif',
#      'period': 11,
#      'pop': '10',
#      'title': 'Monday Night'},
#     {'fcttext': 'Cloudy with occasional showers. High 78F. Winds ESE at 5 to 10 mph. Chance of rain 60%.',
#      'fcttext_metric': 'Overcast with showers at times. High 26C. Winds ESE at 10 to 15 km/h. Chance of rain 60%.',
#      'icon': 'chancerain',
#      'icon_url': 'http://icons.wxug.com/i/c/k/chancerain.gif',
#      'period': 12,
#      'pop': '60',
#      'title': 'Tuesday'},
#     {'fcttext': 'Cloudy with showers. Thunder possible. Low 64F. Winds light and variable. Chance of rain 60%.',
#      'fcttext_metric': 'Cloudy with occasional rain showers. Thunder possible. Low 18C. Winds light and variable. Chance of rain 60%.',
#      'icon': 'nt_chancerain',
#      'icon_url': 'http://icons.wxug.com/i/c/k/nt_chancerain.gif',
#      'period': 13,
#      'pop': '60',
#      'title': 'Tuesday Night'},
#     {'fcttext': 'Variable clouds with scattered thunderstorms. High 82F. Winds SW at 5 to 10 mph. Chance of rain 60%.',
#      'fcttext_metric': 'Scattered showers and thunderstorms. High 29C. Winds SW at 10 to 15 km/h. Chance of rain 50%.',
#      'icon': 'chancetstorms',
#      'icon_url': 'http://icons.wxug.com/i/c/k/chancetstorms.gif',
#      'period': 14,
#      'pop': '60',
#      'title': 'Wednesday'},
#     {'fcttext': 'Scattered thunderstorms during the evening followed by occasional showers overnight. Low near 65F. Winds S at 5 to 10 mph. Chance of rain 60%.',
#      'fcttext_metric': 'Variable clouds with showers and scattered thunderstorms. Storms more numerous during the evening. Low 19C. Winds S at 10 to 15 km/h. Chance of rain 60%.',
#      'icon': 'nt_chancetstorms',
#      'icon_url': 'http://icons.wxug.com/i/c/k/nt_chancetstorms.gif',
#      'period': 15,
#      'pop': '60',
#      'title': 'Wednesday Night'},
#     {'fcttext': 'Variable clouds with scattered thunderstorms. High 82F. Winds WSW at 5 to 10 mph. Chance of rain 60%.',
#      'fcttext_metric': 'Variable clouds with scattered thunderstorms. High 29C. Winds SW at 10 to 15 km/h. Chance of rain 60%.',
#      'icon': 'chancetstorms',
#      'icon_url': 'http://icons.wxug.com/i/c/k/chancetstorms.gif',
#      'period': 16,
#      'pop': '60',
#      'title': 'Thursday'},
#     {'fcttext': 'Partly to mostly cloudy skies with scattered thunderstorms before midnight. Low around 65F. Winds light and variable. Chance of rain 50%.',
#      'fcttext_metric': 'Partly to mostly cloudy skies with scattered thunderstorms before midnight. Low 18C. Winds light and variable. Chance of rain 50%.',
#      'icon': 'nt_chancetstorms',
#      'icon_url': 'http://icons.wxug.com/i/c/k/nt_chancetstorms.gif',
#      'period': 17,
#      'pop': '50',
#      'title': 'Thursday Night'},
#     {'fcttext': 'A shower or two possible early with partly cloudy skies in the afternoon. High near 80F. Winds WNW at 5 to 10 mph. Chance of rain 30%.',
#      'fcttext_metric': 'Partly cloudy skies. High 28C. Winds W at 10 to 15 km/h.',
#      'icon': 'chancerain',
#      'icon_url': 'http://icons.wxug.com/i/c/k/chancerain.gif',
#      'period': 18,
#      'pop': '30',
#      'title': 'Friday'},
#     {'fcttext': 'Mostly cloudy with showers and a few thunderstorms. Low 63F. Winds light and variable. Chance of rain 60%.',
#      'fcttext_metric': 'Mostly cloudy with showers and a few thunderstorms. Low 17C. Winds light and variable. Chance of rain 60%.',
#      'icon': 'nt_chancetstorms',
#      'icon_url': 'http://icons.wxug.com/i/c/k/nt_chancetstorms.gif',
#      'period': 19,
#      'pop': '60',
#      'title': 'Friday Night'}]}},
#  'moon_phase': {'ageOfMoon': '6',
#   'current_time': {'hour': '22', 'minute': '01'},
#   'hemisphere': 'North',
#   'moonrise': {'hour': '10', 'minute': '56'},
#   'moonset': {'hour': '0', 'minute': '16'},
#   'percentIlluminated': '33',
#   'phaseofMoon': 'Waxing Crescent',
#   'sunrise': {'hour': '6', 'minute': '13'},
#   'sunset': {'hour': '20', 'minute': '12'}},
#  'query_zone': '024',
#  'response': {'features': {'alerts': 1,
#    'astronomy': 1,
#    'conditions': 1,
#    'currenthurricane': 1,
#    'forecast10day': 1},
#   'termsofService': 'http://www.wunderground.com/weather/api/d/terms.html',
#   'version': '0.1'},
#  'sun_phase': {'sunrise': {'hour': '6', 'minute': '13'},
#   'sunset': {'hour': '20', 'minute': '12'}}}

# %%
class Conditions():
    def __init__(self, data):
        self.location = data['display_location']['full']
        self.time = data['observation_time']
        self.weather = data['weather']
        self.temp = data['temperature_string']
        self.humidity = data['relative_humidity']
        self.wind_spd = data['wind_mph']
        self.pressure = data['pressure_mb']
        self.pressure_trend = data['pressure_trend']
        self.precip = data['precip_today_string']
        
    def display_conditions(self):
        print('Current conditions in ' + self.location)
        print(self.time)
        print('*' * 40)
        print('Temperature: ' + self.temp)
        print('Conditions: ' + self.weather)
        print('Humidity: ' + self.humidity)
        print('Wind Speed :' + self.wind_spd)
        print('Barometric Pressure: ' + self.pressure + self.pressure_trend)
        print('Precipitation: ' + self.precip)

# %%
conditions = Conditions(data['current_observation'])

# %%
conditions.pressure
# Out:
# '1019'

# %%
class TenDayForecast():
    def __init__(self, data):
        self.days = self.get_days(data)
        
    def get_days(self, data):
        days = []
        for i in range(0, 10):
#             night_counter = 1
            new_day = DayForecast(data, i)
            days.append(new_day)
#             night_counter += 2
        return days
    
    def display_forecast(self):
        for day in self.days:
            day.display_day()

# %%
class DayForecast():
    def __init__(self, data, day):
        self.day_data = data['simpleforecast']['forecastday'][day]
        self.morning =  data['txt_forecast']['forecastday'][day * 2]
        self.evening = data['txt_forecast']['forecastday'][day * 2 + 1]
        
        self.date = ' '.join((self.day_data['date']['monthname'], str(self.day_data['date']['day'])))
        
        self.morning_title = self.morning['title']
        self.evening_title = self.evening['title']
        
        self.morning_summary = self.morning['fcttext']
        self.evening_summary = self.evening['fcttext']
        
        self.high = self.day_data['high']['fahrenheit']
        self.low = self.day_data['low']['fahrenheit']
        
        
    def display_day(self):
        print('*' * 20 + '\n')
        print(self.morning_title, self.date)
        print('-' * 10)
        print(self.morning_summary)
        print('High: ', self.high)
        print('Low: ', self.low, '\n')
        print(self.evening_title)
        print('-' * 10)
        print(self.evening_summary, '\n')

# %%
ten_day = TenDayForecast(data['forecast'])

# %%
ten_day.days[0].date
# Out:
# 'May 11'

# %%
ten_day.display_forecast()
# Out:
# ********************
#
# Wednesday May 11
# ----------
# Partly cloudy. Lows overnight in the low 60s.
# High:  81
# Low:  62
#
# Wednesday Night
# ----------
# Partly to mostly cloudy. A stray shower or thunderstorm is possible. Low 62F. Winds light and variable.
#
# ********************
#
# Thursday May 12
# ----------
# Cloudy early with partial sunshine expected late. A stray shower or thunderstorm is possible. High 82F. Winds light and variable.
# High:  82
# Low:  65
#
# Thursday Night
# ----------
# Scattered thunderstorms in the evening. Partly cloudy skies overnight. Low around 65F. Winds light and variable. Chance of rain 50%.
#
# ********************
#
# Friday May 13
# ----------
# Scattered showers and thunderstorms. High 78F. Winds W at 5 to 10 mph. Chance of rain 60%.
# High:  78
# Low:  56
#
# Friday Night
# ----------
# Partly cloudy skies. Low 56F. Winds light and variable.
#
# ********************
#
# Saturday May 14
# ----------
# Sunshine and clouds mixed. A stray shower or thunderstorm is possible. High 82F. Winds W at 10 to 15 mph.
# High:  82
# Low:  49
#
# Saturday Night
# ----------
# Some clouds early will give way to generally clear conditions overnight. Low 49F. Winds NW at 5 to 10 mph.
#
# ********************
#
# Sunday May 15
# ----------
# Mainly sunny. High 72F. Winds WNW at 5 to 10 mph.
# High:  72
# Low:  51
#
# Sunday Night
# ----------
# Clear skies with a few passing clouds. Low 51F. Winds light and variable.
#
# ********************
#
# Monday May 16
# ----------
# Partly cloudy skies. High 73F. Winds light and variable.
# High:  73
# Low:  55
#
# Monday Night
# ----------
# A few clouds. Low near 55F. Winds light and variable.
#
# ********************
#
# Tuesday May 17
# ----------
# Cloudy with occasional showers. High 78F. Winds ESE at 5 to 10 mph. Chance of rain 60%.
# High:  78
# Low:  64
#
# Tuesday Night
# ----------
# Cloudy with showers. Thunder possible. Low 64F. Winds light and variable. Chance of rain 60%.
#
# ********************
#
# Wednesday May 18
# ----------
# Variable clouds with scattered thunderstorms. High 82F. Winds SW at 5 to 10 mph. Chance of rain 60%.
# High:  82
# Low:  65
#
# Wednesday Night
# ----------
# Scattered thunderstorms during the evening followed by occasional showers overnight. Low near 65F. Winds S at 5 to 10 mph. Chance of rain 60%.
#
# ********************
#
# Thursday May 19
# ----------
# Variable clouds with scattered thunderstorms. High 82F. Winds WSW at 5 to 10 mph. Chance of rain 60%.
# High:  82
# Low:  65
#
# Thursday Night
# ----------
# Partly to mostly cloudy skies with scattered thunderstorms before midnight. Low around 65F. Winds light and variable. Chance of rain 50%.
#
# ********************
#
# Friday May 20
# ----------
# A shower or two possible early with partly cloudy skies in the afternoon. High near 80F. Winds WNW at 5 to 10 mph. Chance of rain 30%.
# High:  80
# Low:  63
#
# Friday Night
# ----------
# Mostly cloudy with showers and a few thunderstorms. Low 63F. Winds light and variable. Chance of rain 60%.

# %%
data['forecast']['txt_forecast']['forecastday'][:2]
